# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series
# Series adalah ketika kita mengambil 1 kolom saja maka itu termasuk konsep series
# # Multiple Columns
# Ketika kita mengambil lebih dari 1 kolom maka disebut multiple Columns
# # .drop
# Jika kita ingin menghapus kolom yang tidak kita inginkan gunakan
# Misal menghapus dataframe kolom => .drop('nama_kolom', axis=1)
# Misal menghapus dataframe baris => .drop('index_baris', axis=0)

# %%
# D&D characters data
characters_data = {
  'name': ['Thorne', 'Elira', 'Glim', 'Brug', 'Nyx', 'Kael', 'Mira', 'Drogan', 'Zara', 'Fenwick'],
  'race': ['Elf', 'Human', 'Gnome', 'Half-Orc', 'Tiefling', 'Dragonborn', 'Halfling', 'Dwarf', 'Aasimar', 'Goblin'],
  'class': ['Ranger', 'Cleric', 'Wizard', 'Barbarian', 'Rogue', 'Paladin', 'Bard', 'Fighter', 'Sorcerer', 'Warlock'],
  'level': [5, 3, 4, 2, 6, 7, 3, 5, 4, 2],
  'hp': [42, 28, 33, 25, 48, 56, 30, 44, 36, 24],
  'alignment': [
    'Chaotic Good', 'Lawful Good', 'Neutral', 'Chaotic Neutral', 'Chaotic Evil',
    'Lawful Neutral', 'Neutral Good', 'Neutral', 'Chaotic Good', 'Lawful Evil'
  ]
}

# Create the DataFrame
characters = pd.DataFrame(characters_data)
characters
# Out:
#       name        race      class  level  hp        alignment
# 0   Thorne         Elf     Ranger      5  42     Chaotic Good
# 1    Elira       Human     Cleric      3  28      Lawful Good
# 2     Glim       Gnome     Wizard      4  33          Neutral
# 3     Brug    Half-Orc  Barbarian      2  25  Chaotic Neutral
# 4      Nyx    Tiefling      Rogue      6  48     Chaotic Evil
# 5     Kael  Dragonborn    Paladin      7  56   Lawful Neutral
# 6     Mira    Halfling       Bard      3  30     Neutral Good
# 7   Drogan       Dwarf    Fighter      5  44          Neutral
# 8     Zara     Aasimar   Sorcerer      4  36     Chaotic Good
# 9  Fenwick      Goblin    Warlock      2  24      Lawful Evil

# %%
# Ambil kolom nama dengan membuat variabel characters_names
characters_names = characters['name']
characters_names
# Print tipe data dari characters_names
type(characters_names)
# Out:
# pandas.Series

# %%
# Ambil kolom nama, level, dan hp dengan membuat variabel basic_stats
basic_stats = characters[['name', 'level', 'hp']]
basic_stats
# Out:
#       name  level  hp
# 0   Thorne      5  42
# 1    Elira      3  28
# 2     Glim      4  33
# 3     Brug      2  25
# 4      Nyx      6  48
# 5     Kael      7  56
# 6     Mira      3  30
# 7   Drogan      5  44
# 8     Zara      4  36
# 9  Fenwick      2  24

# %%
# Buat variabel baru berisi semua informasi kecuali alginment
removed_alignment = characters.drop('alignment', axis=1)
removed_alignment
# Out:
#       name        race      class  level  hp
# 0   Thorne         Elf     Ranger      5  42
# 1    Elira       Human     Cleric      3  28
# 2     Glim       Gnome     Wizard      4  33
# 3     Brug    Half-Orc  Barbarian      2  25
# 4      Nyx    Tiefling      Rogue      6  48
# 5     Kael  Dragonborn    Paladin      7  56
# 6     Mira    Halfling       Bard      3  30
# 7   Drogan       Dwarf    Fighter      5  44
# 8     Zara     Aasimar   Sorcerer      4  36
# 9  Fenwick      Goblin    Warlock      2  24
