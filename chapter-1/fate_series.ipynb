# %%
import pandas as pd

# %%
camelot_servants = {
    'Name': ['Artoria Pendragon', 'Tristan', 'Percival', 'Bedivere', 'Lancelot', 'Gawain', 'Galahad'],
    'Class': ['Saber', 'Archer', 'Lancer', 'Saber', 'Saber', 'Saber', 'Shielder'],
    'Origin': ['Fate/stay night', 'Fate/stay night', 'Fate/Grand Order', 'Fate/stay night', 'Fate/stay night', 'Fate/Grand Order', 'Fate/Grand Order'],
    'Noble Phantasm': ['Excalibur', 'Tristan\'s Bow', 'Chastiefol', 'Excalibur Galatine', 'Arondight', 'Excalibur Galatine', 'Highroad Camelot']
}

df = pd.DataFrame(camelot_servants)
df

# Save to CSV
df.to_csv('camelot_servants.csv', index=False)

# %%
babylon_servants = {
    'Name': ['Gilgamesh', 'Enkidu', 'Ishtar', 'Ereshkigal', 'Nabû', 'Tiamat', 'Quetzalcoatl'],
    'Class': ['Archer', 'Lancer', 'Archer', 'Lancer', 'Caster', 'Saber', 'Rider'],
    'Origin': ['Fate/stay night', 'Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order'],
    'Noble Phantasm': ['Gate of Babylon', 'Enuma Elish', 'An Gal Tā Kigal Shē', 'Kur Kigal Irkalla', 'Tablet of Destinies', 'Chaos Meteor', 'Quetzalcoatl\'s Wind God']
}

df = pd.DataFrame(babylon_servants)
df
# Out:
#            Name   Class            Origin           Noble Phantasm
# 0     Gilgamesh  Archer   Fate/stay night          Gate of Babylon
# 1        Enkidu  Lancer  Fate/Grand Order              Enuma Elish
# 2        Ishtar  Archer  Fate/Grand Order      An Gal Tā Kigal Shē
# 3    Ereshkigal  Lancer  Fate/Grand Order        Kur Kigal Irkalla
# 4          Nabû  Caster  Fate/Grand Order      Tablet of Destinies
# 5        Tiamat   Saber  Fate/Grand Order             Chaos Meteor
# 6  Quetzalcoatl   Rider  Fate/Grand Order  Quetzalcoatl's Wind God

# %%
charlemagne_paladin = {
    'Name': ['Charlemagne', 'Roland', 'Oliver', 'Renaud de Montauban', 'Ogier the Dane', 'Baldwin', 'Turpin'],
    'Class': ['Saber', 'Saber', 'Saber', 'Saber', 'Saber', 'Saber', 'Rider'],
    'Origin': ['Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order'],
    'Noble Phantasm': ['Joyeuse Ordre', 'Durandal', 'Durandal', 'Durandal', 'Hrunting', 'Axe of Charlemagne', 'Holy Lance']   
}

df = pd.DataFrame(charlemagne_paladin)
df

# Cek 2 data teratasa
df.head(2)
# Cek struktur data frame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            7 non-null      str
#  1   Class           7 non-null      str
#  2   Origin          7 non-null      str
#  3   Noble Phantasm  7 non-null      str
# dtypes: str(4)
# memory usage: 356.0 bytes

# %%
# Assassin of the mountains
assassin_mountains = {
    'name': ['Hassan-i Sabbah', 'Hassan of the Cursed Arm', 'Hassan of the Serenity', 'Hassan of the Hundred Faces'],
    'class': ['Grand Assassin', 'Assassin', 'Assassin', 'Assassin'],
    'origin': ['Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order', 'Fate/Grand Order'],
    'weapon': ['Sword', 'Dagger', 'Poison', 'Kunai'],
    'noble_phantasm': ['Azrael', 'Killing Stone', 'Mumū', 'Thousand Faces']
}
df = pd.DataFrame(assassin_mountains)
df
df.describe(include='all')

df.to_csv('assassin_mountains.csv', index=False)

# Accessing single column
df['name']
df.name
# Accessing multiple columns
df[['name', 'class', 'weapon']]
# Out:
# 0                Hassan-i Sabbah
# 1       Hassan of the Cursed Arm
# 2         Hassan of the Serenity
# 3    Hassan of the Hundred Faces
# Name: name, dtype: str
