# %%
import pandas as pd
import numpy as np

# %%
# Membuat data dummy movies
data_movies = {
    'title': ['The Matrix', 'Inception', 'Parasite', 'The Lion King', 'Everything Everywhere All at Once'],
    'release_date': ['1999-03-31', '2010-07-16', '2019-05-30', '1994-06-15', '2022-03-11'],
    'genre': ['Sci-Fi', 'Sci-Fi', 'Thriller', 'Animation', 'Action'],
    'studio': ['Warner Bros.', 'Warner Bros.', 'CJ Entertainment', 'Disney', 'A24'],
    'budget': [63000000.0, 160000000.0, np.nan, 45000000.0, 25000000.0],
    'box_office': [466000000.0, 836800000.0, 263000000.0, 968500000.0, np.nan],
    'runtime_minutes': [136, 148, 132, 88, 139],
    'rating': [8.7, 8.8, 8.5, 8.5, 8.0]
}

movies = pd.DataFrame(data_movies)
movies
# Out:
#                                title release_date      genre  \
# 0                         The Matrix   1999-03-31     Sci-Fi
# 1                          Inception   2010-07-16     Sci-Fi
# 2                           Parasite   2019-05-30   Thriller
# 3                      The Lion King   1994-06-15  Animation
# 4  Everything Everywhere All at Once   2022-03-11     Action
#
#              studio       budget   box_office  runtime_minutes  rating
# 0      Warner Bros.   63000000.0  466000000.0              136     8.7
# 1      Warner Bros.  160000000.0  836800000.0              148     8.8
# 2  CJ Entertainment          NaN  263000000.0              132     8.5
# 3            Disney   45000000.0  968500000.0               88     8.5
# 4               A24   25000000.0          NaN              139     8.0

# %%
# Cek informasi dasar DataFrame
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            5 non-null      str
#  1   release_date     5 non-null      str
#  2   genre            5 non-null      str
#  3   studio           5 non-null      str
#  4   budget           4 non-null      float64
#  5   box_office       4 non-null      float64
#  6   runtime_minutes  5 non-null      int64
#  7   rating           5 non-null      float64
# dtypes: float64(3), int64(1), str(4)
# memory usage: 452.0 bytes

# %%
# Cek Statistik dataframe
movies.describe(include='all')
# Out:
#              title release_date   genre        studio        budget  \
# count            5            5       5             5  4.000000e+00
# unique           5            5       4             4           NaN
# top     The Matrix   1999-03-31  Sci-Fi  Warner Bros.           NaN
# freq             1            1       2             2           NaN
# mean           NaN          NaN     NaN           NaN  7.325000e+07
# std            NaN          NaN     NaN           NaN  5.987974e+07
# min            NaN          NaN     NaN           NaN  2.500000e+07
# 25%            NaN          NaN     NaN           NaN  4.000000e+07
# 50%            NaN          NaN     NaN           NaN  5.400000e+07
# 75%            NaN          NaN     NaN           NaN  8.725000e+07
# max            NaN          NaN     NaN           NaN  1.600000e+08
#
#           box_office  runtime_minutes    rating
# count   4.000000e+00         5.000000  5.000000
# unique           NaN              NaN       NaN
# ...
